# %%
subjects = ["Python", "Math", "AI", "Data"]
print(subjects)
print(subjects[0])
print(subjects[-1])
# Out:
# ['Python', 'Math', 'AI', 'Data']

# %%
students = [
    {"name": "Palak", "marks": 92, "attendance": 95, "lab_assignment": True,"grade":"A+"},
    {"name": "Akshat", "marks": 75, "attendance": 85, "lab_assignment": True,"grade":"F"},
    {"name": "Rishi", "marks": 58, "attendance": 60, "lab_assignment": True,"grade":"A"},
    {"name": "Aman", "marks": 88, "attendance": 90, "lab_assignment": False,"grade":"A+"},
    {"name": "Ananya", "marks": 35, "attendance": 80, "lab_assignment": True,"grade":"B"}
]

for student in students:
    if student.get("grade") == "A+":
        print(student.get("name"))
# Out:
# Palak
# Aman

# %%
marks = 72
if marks>80:
  print("Distinction")
elif marks>=40:
  print("Pass")
else:
  print("Fail")

# %%
if marks%2==0:
  print("Even")
else:
  print("Odd")

# %%
age=34
if age>=20:
  print("Adult")
elif age>13 and age<20:
  print("Teenager")
else:
  print("Child")

# %%
students = [
    {"name": "Palak", "marks": 92, "attendance": 95, "lab_assignment": True},
    {"name": "Akshat", "marks": 75, "attendance": 85, "lab_assignment": True},
    {"name": "Rishi", "marks": 58, "attendance": 60, "lab_assignment": True},
    {"name": "Aman", "marks": 88, "attendance": 90, "lab_assignment": False},
    {"name": "Ananya", "marks": 35, "attendance": 80, "lab_assignment": True}
]

for student in students:
    if student["lab_assignment"] == False:
        result = "Lab Assignment Not Submitted"
    elif student["attendance"] < 75:
        result = "Low Attendance"
    elif student["marks"] >= 70:
        result = "Distinction"
    elif student["marks"] >= 40:
        result = "Pass"
    else:
        result = "Fail"

    print(student["name"], "-", result)
